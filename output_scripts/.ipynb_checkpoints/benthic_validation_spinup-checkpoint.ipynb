# %%
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import pandas as pd
import seaborn as sns
import xarray as xr
from scipy.spatial import cKDTree
from scipy.stats import gaussian_kde, linregress, pearsonr

# %%
# ──────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ──────────────────────────────────────────────────────────────────────────────

POSTPROC_DIR = Path("/export/lv9/projects/dws/results/validation/benthos/")
BASE_OUTPUT_DIR = Path("/export/lv9/projects/dws/model_output/archived_runs/")

OBS_CSV = {
    "SIBES": POSTPROC_DIR / "feeding_groups_gC_m2_ecotopes_SIBES.csv",
    "SUBES": POSTPROC_DIR / "feeding_groups_gC_m2_ecotopes_SUBES.csv",
}

SPINUP_NAMES = ["spinup_01", "spinup_02", "spinup_03", "spinup_04", "spinup_05", "spinup_06"]

# NetCDF filename pattern – {year} is substituted for each observation year
# present inside the spinup directory.
NC_PATTERN = "dws_500m.3d.{year}*.nc"

# Benthic variables to validate
VALIDATION_VARS = ["Y1c", "Y2c", "Y3c", "Y5c"]

# Observation column corresponding to each model variable
OBS_COL = {
    "Y1c": "epibenthos_Y1_c",
    "Y2c": "deposit_feeders_Y2_c",
    "Y3c": "suspension_feeders_Y3_c",
    "Y5c": "endobenthos_Y5_c",
}

# Human-readable labels for plot titles
VAR_LABEL = {
    "Y1c": "Epibenthos (Y1c)",
    "Y2c": "Deposit feeders (Y2c)",
    "Y3c": "Suspension feeders (Y3c + Yy3c)",
    "Y5c": "Endobenthos / predators (Y5c)",
}

# Model fill value for lonc/latc (from ncdump valid_range)
LON_FILL = -999.0
LAT_FILL = -999.0
LON_VALID = (-180.0, 180.0)
LAT_VALID = (-90.0, 90.0)

# Bathymetry fill/missing value used for land cells (from ncdump: missing_value = -10.)
# Only cells with bathymetry strictly greater than this are wet and enter the KD-tree.
BATHY_FILL = -10.0

# Unit conversion: model outputs mg C m⁻² → g C m⁻²
MGC_TO_GC = 1.0 / 1000.0

# Canonical basin name map (fixes SIBES/SUBES spelling inconsistency)
BASIN_CANONICAL = {
    "Eijerlandse Gat": "Eierlandse Gat",  # SUBES typo → SIBES spelling
}

# Output figure directory
OUT_DIR = POSTPROC_DIR / "all_spinups"
OUT_DIR.mkdir(parents=True, exist_ok=True)

# ── Visual style ──────────────────────────────────────────────────────────────
# Colorblind-safe source colours (from seaborn "colorblind" palette, blue/orange)
SOURCE_COLORS  = {"SIBES": "#0173b2", "SUBES": "#de8f05"}
SOURCE_MARKERS = {"SIBES": "o",       "SUBES": "s"}

# Spinup accent colours: evenly-spaced HUSL hues – perceptually uniform,
# distinct, and not overly saturated.
_husl = sns.color_palette("husl", len(SPINUP_NAMES)).as_hex()
SPINUP_COLORS = dict(zip(
    SPINUP_NAMES,
    _husl,
))

# %%
# ──────────────────────────────────────────────────────────────────────────────
# HELPER FUNCTIONS
# ──────────────────────────────────────────────────────────────────────────────


def load_observations() -> pd.DataFrame:
    """Load and clean SIBES + SUBES CSVs into a single DataFrame."""
    frames = []
    for source, csv_path in OBS_CSV.items():
        df = pd.read_csv(csv_path)
        df["date"] = pd.to_datetime(df["date"], errors="coerce")
        df["source"] = source
        frames.append(df)

    obs = pd.concat(frames, ignore_index=True)

    obs["tidal_basin_name"] = obs["tidal_basin_name"].replace(BASIN_CANONICAL)

    obs = obs.dropna(subset=["date", "x", "y", "tidal_basin_name"]).copy()
    obs["year"] = obs["date"].dt.year
    return obs


def build_kdtree(lon2d: np.ndarray, lat2d: np.ndarray, bathy2d: np.ndarray):
    """
    Build a cKDTree of valid, **wet** model cell centres.

    FIX B1 (extended): the lon/lat valid-range mask excludes fill values (-999)
    but does not exclude land.  Land cells carry bathymetry == BATHY_FILL (-10),
    so adding ``bathy2d > BATHY_FILL`` to the mask restricts the tree to wet
    cells only.  Observations that fall on tidal flats slightly outside the
    numerical domain will then snap to the nearest wet neighbour instead of
    returning a fill-value (NaN) model value.
    """

    mask = (
        (lon2d > LON_VALID[0])
        & (lon2d < LON_VALID[1])
        & (lat2d > LAT_VALID[0])
        & (lat2d < LAT_VALID[1])
        & (bathy2d > BATHY_FILL)   # exclude land cells
    )
    flat_lon = lon2d[mask]
    flat_lat = lat2d[mask]
    flat_iy, flat_ix = np.where(mask)
    tree = cKDTree(np.column_stack([flat_lon, flat_lat]))
    return tree, flat_iy, flat_ix


def load_model_year(spinup_dir: Path, year: int) -> xr.Dataset | None:
    """
    Open all monthly NetCDF files for *year* in *spinup_dir*, deduplicate
    time steps, and return a merged dataset with only the needed variables.

    FIX B2: variables and coordinates are selected separately so that
    xr.Dataset.__getitem__ is not asked to retrieve coordinate names as
    if they were data variables.
    """
    nc_files = sorted(spinup_dir.glob(NC_PATTERN.format(year=year)))
    if not nc_files:
        return None

    data_vars_needed = ["Y1c", "Y2c", "Y3c", "Yy3c", "Y5c"]

    datasets = []
    for fp in nc_files:
        with xr.open_dataset(fp, mask_and_scale=False) as dsi:
            # Check all required variables exist
            missing = [v for v in data_vars_needed if v not in dsi.data_vars]
            if missing:
                warnings.warn(f"{fp.name}: missing vars {missing}, skipping file.")
                continue

            dsi_sub = dsi[data_vars_needed].load()

        # Deduplicate time axis within this file
        t_idx = pd.DatetimeIndex(pd.to_datetime(dsi_sub["time"].values))
        if t_idx.has_duplicates:
            dsi_sub = dsi_sub.isel(time=~t_idx.duplicated())

        datasets.append(dsi_sub)

    if not datasets:
        return None

    ds = xr.concat(
        datasets,
        dim="time",
        data_vars="minimal",
        coords="minimal",
        compat="override",
        join="override",
    )
    ds = ds.sortby("time")

    # Final deduplication across files
    t_idx = pd.DatetimeIndex(pd.to_datetime(ds["time"].values))
    if t_idx.has_duplicates:
        ds = ds.isel(time=~t_idx.duplicated())

    return ds


def nearest_time_idx(model_times: pd.DatetimeIndex, obs_times: np.ndarray) -> np.ndarray:
    """Return index into model_times of the nearest time for each obs timestamp."""
    mt = model_times.to_numpy(dtype="datetime64[ns]")
    ot = np.asarray(obs_times, dtype="datetime64[ns]")

    right = np.searchsorted(mt, ot, side="left")
    left = np.clip(right - 1, 0, len(mt) - 1)
    right = np.clip(right, 0, len(mt) - 1)

    left_diff = np.abs(ot - mt[left]).astype(np.int64)
    right_diff = np.abs(mt[right] - ot).astype(np.int64)
    use_right = right_diff < left_diff
    return np.where(use_right, right, left)


def model_da_for_var(ds: xr.Dataset, mvar: str) -> xr.DataArray:
    """
    Return the model DataArray for *mvar*.
    For Y3c (adult suspension feeders) we sum adult + young stages,
    which matches what the field data records as total suspension feeders.
    """
    if mvar == "Y3c":
        return ds["Y3c"] + ds["Yy3c"]
    return ds[mvar]


def scatter_metrics(x_obs: np.ndarray, y_mod: np.ndarray) -> dict:
    """Compute bias, RMSE, and Pearson r for a pair of arrays."""
    valid = np.isfinite(x_obs) & np.isfinite(y_mod)
    x, y = x_obs[valid], y_mod[valid]
    if len(x) < 3:
        return {"n": len(x), "bias": np.nan, "rmse": np.nan, "r": np.nan}
    bias = float(np.mean(y - x))
    rmse = float(np.sqrt(np.mean((y - x) ** 2)))
    r, _ = pearsonr(x, y)
    return {"n": len(x), "bias": bias, "rmse": rmse, "r": float(r)}

# %%
# ──────────────────────────────────────────────────────────────────────────────
# MAIN COLLOCATION LOOP
# ──────────────────────────────────────────────────────────────────────────────


def collate_spinup(spinup_name: str, obs: pd.DataFrame) -> pd.DataFrame | None:
    """
    For one spinup run, find model values at every observation point+time
    and return an augmented DataFrame with model columns appended.
    """
    spinup_dir = BASE_OUTPUT_DIR / spinup_name
    if not spinup_dir.exists():
        print(f"  [WARN] {spinup_dir} does not exist – skipping.")
        return None

    # Determine which years of observations to match
    obs_years = sorted(obs["year"].unique())

    # We need lonc/latc for the KD-tree; load them from the first available file
    # (they are static grid coordinates – identical across all time steps/years)
    any_nc = next(spinup_dir.glob("dws_500m.3d.*.nc"), None)
    if any_nc is None:
        print(f"  [WARN] No NetCDF files in {spinup_dir} – skipping.")
        return None

    with xr.open_dataset(any_nc, mask_and_scale=False) as ds_grid:
        lon2d = ds_grid["lonc"].values.copy()
        lat2d = ds_grid["latc"].values.copy()
        bathy2d = ds_grid["bathymetry"].values.copy()

    tree, flat_iy, flat_ix = build_kdtree(lon2d, lat2d, bathy2d)


    # Spatial nearest-neighbour (same tree for all years)
    obs_coords = np.column_stack([obs["x"].to_numpy(), obs["y"].to_numpy()])
    _, nn_idx = tree.query(obs_coords, k=1)
    # FIX B4: ensure integer dtype for isel indices
    obs = obs.copy()
    obs["iy"] = flat_iy[nn_idx].astype(int)
    obs["ix"] = flat_ix[nn_idx].astype(int)

    # Initialise model columns with NaN
    for mvar in VALIDATION_VARS:
        obs[f"{mvar}_model_gC_m2"] = np.nan

    # Process year by year to keep memory manageable
    for year in obs_years:
        year_mask = obs["year"] == year
        if not year_mask.any():
            continue

        ds = load_model_year(spinup_dir, year)
        if ds is None:
            print(f"  [INFO] {spinup_name}: no model files for {year} – obs skipped.")
            continue

        model_times = pd.DatetimeIndex(pd.to_datetime(ds["time"].values))

        obs_year = obs.loc[year_mask]
        it_arr = nearest_time_idx(model_times, obs_year["date"].to_numpy(dtype="datetime64[ns]"))

        it_xr = xr.DataArray(it_arr.astype(int), dims="obs")
        # FIX B4: cast iy/ix to int explicitly
        iy_xr = xr.DataArray(obs_year["iy"].to_numpy().astype(int), dims="obs")
        ix_xr = xr.DataArray(obs_year["ix"].to_numpy().astype(int), dims="obs")

        for mvar in VALIDATION_VARS:
            vals = (
                model_da_for_var(ds, mvar)
                .isel(time=it_xr, yc=iy_xr, xc=ix_xr)
                .values
                * MGC_TO_GC
            )
            # Replace fill values (-9999 * MGC_TO_GC) with NaN
            vals = np.where(vals < -1.0, np.nan, vals)  # any large-negative is fill
            obs.loc[year_mask, f"{mvar}_model_gC_m2"] = vals

    obs["spinup"] = spinup_name
    return obs

# %%
# ──────────────────────────────────────────────────────────────────────────────
# PLOTTING
# ──────────────────────────────────────────────────────────────────────────────

def _apply_theme() -> None:
    """Set a consistent seaborn/matplotlib theme for publication."""
    # Use 'ticks' style instead of 'whitegrid' for cleaner scientific look
    sns.set_theme(style="ticks")
    
    plt.rcParams.update({
        # Font settings: Nature prefers Arial or Helvetica
        "font.family": "sans-serif",
        "font.sans-serif": ["Arial", "Helvetica", "DejaVu Sans"],
        "pdf.fonttype": 42,
        "ps.fonttype": 42,
        
        # Sizing (Increase these to scale up all text globally)
        "font.size": 11,
        "axes.titlesize": 13,
        "axes.labelsize": 12,
        "xtick.labelsize": 10,
        "ytick.labelsize": 10,
        "legend.fontsize": 10,
        
        # Axis styling
        "axes.spines.top": False,
        "axes.spines.right": False,
        "axes.edgecolor": "black",
        "axes.linewidth": 1.0,
        "figure.facecolor": "white",
        "savefig.facecolor": "white",
    })

def plot_scatter_all_spinups(all_collocated: list[pd.DataFrame]) -> None:
    """
    One figure per feeding group; 4 subpanels side-by-side (one per spinup).
    """
    _apply_theme()
    n_sp = len(all_collocated)

    # Pre-compute shared 99th-percentile ceiling per variable
    global_max: dict[str, float] = {}
    for mvar in VALIDATION_VARS:
        ocol = OBS_COL[mvar]
        all_v: list[float] = []
        for df in all_collocated:
            x = df[ocol].to_numpy()
            y = df[f"{mvar}_model_gC_m2"].to_numpy()
            v = np.isfinite(x) & np.isfinite(y) & (x >= 0) & (y >= 0)
            all_v.extend(x[v].tolist())
            all_v.extend(y[v].tolist())
        global_max[mvar] = float(np.percentile(all_v, 99)) * 1.08 if all_v else 1.0

    for mvar in VALIDATION_VARS:
        ocol = OBS_COL[mvar]
        gmax = global_max[mvar]

        fig, axes = plt.subplots(
            1, n_sp,
            figsize=(4.2 * n_sp, 4.4),
            constrained_layout=True,
            sharex=True, sharey=True,
        )
        if n_sp == 1:
            axes = [axes]

        for ax, df in zip(axes, all_collocated):
            spinup   = df["spinup"].iloc[0]
            sp_color = SPINUP_COLORS.get(spinup, "#888888")

            # ── Per-source scatter ──
            for source in ["SIBES", "SUBES"]:
                mask = df["source"] == source
                x = df.loc[mask, ocol].to_numpy()
                y = df.loc[mask, f"{mvar}_model_gC_m2"].to_numpy()
                v = np.isfinite(x) & np.isfinite(y) & (x >= 0) & (y >= 0)
                if not v.any():
                    continue
                ax.scatter(
                    x[v], y[v],
                    s=14, alpha=0.35, linewidths=0,
                    color=SOURCE_COLORS[source],
                    marker=SOURCE_MARKERS[source],
                    label=source,
                    rasterized=True,
                    zorder=2,
                )

            # ── OLS regression line (all sources combined) ──
            x_all = df[ocol].to_numpy()
            y_all = df[f"{mvar}_model_gC_m2"].to_numpy()
            v_all = np.isfinite(x_all) & np.isfinite(y_all) & (x_all >= 0) & (y_all >= 0)
            if v_all.sum() > 3:
                slope, intercept, *_ = linregress(x_all[v_all], y_all[v_all])
                x_fit = np.array([0.0, gmax])
                ax.plot(x_fit, slope * x_fit + intercept,
                        color=sp_color, lw=1.8, ls="-", alpha=0.9,
                        zorder=3, label="OLS fit")

            # ── 1:1 reference line ──
            ax.plot([0, gmax], [0, gmax],
                    color="#666666", lw=1.0, ls="--", zorder=1, label="1:1")

            ax.set_xlim(0, gmax)
            ax.set_ylim(0, gmax)

            # ── Metrics box (bottom-right, away from the cloud) ──
            m = scatter_metrics(x_all, y_all)
            met_lines = [
                f"$n$  = {m['n']:,}",
                f"bias = {m['bias']:+.2f}",
                f"RMSE = {m['rmse']:.2f}",
                f"$r$   = {m['r']:.2f}",
            ]
            ax.text(
                0.97, 0.04, "\n".join(met_lines),
                transform=ax.transAxes, va="bottom", ha="right",
                size="small", linespacing=1.55,
                family="monospace",
                bbox=dict(boxstyle="round,pad=0.4", fc="white",
                          ec=sp_color, lw=1.2, alpha=0.88),
                zorder=5,
            )

            # ── Spinup label ──
            ax.set_title(spinup.replace("_", " "), color=sp_color, fontweight="bold", pad=5)
            ax.set_xlabel("Observed (gC m⁻²)", labelpad=4)
            if ax is axes[0]:
                ax.set_ylabel("Modelled (gC m⁻²)", labelpad=4)

            ax.xaxis.set_major_locator(mticker.MaxNLocator(4, prune="both"))
            ax.yaxis.set_major_locator(mticker.MaxNLocator(4, prune="both"))

        # ── Shared legend (SIBES, SUBES, 1:1 only) ──
        handles, labels = axes[0].get_legend_handles_labels()
        keep = [(h, l) for h, l in zip(handles, labels)
                if l in ("SIBES", "SUBES", "1:1")]
        if keep:
            hs, ls = zip(*keep)
            fig.legend(hs, ls, loc="lower center", ncol=len(keep),
                       framealpha=0.9, edgecolor="#cccccc",
                       bbox_to_anchor=(0.5, -0.06))

        fig.suptitle(VAR_LABEL[mvar], fontweight="bold", y=1.01, size="large")

        # Changed to PDF output
        out_pdf = OUT_DIR / f"scatter_{mvar}_all_spinups.pdf"
        fig.savefig(out_pdf, dpi=300, bbox_inches="tight")
        plt.close(fig)
        print(f"Saved: {out_pdf}")


def plot_error_histograms(all_collocated: list[pd.DataFrame]) -> None:
    """
    One figure per feeding group; rows = spinup runs, columns = SIBES / SUBES.
    """
    _apply_theme()
    sources   = ["SIBES", "SUBES"]
    n_spinups = len(all_collocated)

    for mvar in VALIDATION_VARS:
        ocol = OBS_COL[mvar]

        # Symmetric shared x-axis: 99th percentile of |errors| across all panels
        all_errs: list[float] = []
        for df in all_collocated:
            for src in sources:
                mask = df["source"] == src
                x = df.loc[mask, ocol].to_numpy()
                y = df.loc[mask, f"{mvar}_model_gC_m2"].to_numpy()
                v = np.isfinite(x) & np.isfinite(y)
                if v.any():
                    all_errs.extend((y[v] - x[v]).tolist())
        xlim_abs = float(np.percentile(np.abs(all_errs), 99)) * 1.1 if all_errs else 1.0

        fig, axes = plt.subplots(
            n_spinups, len(sources),
            figsize=(5.0 * len(sources), 3.4 * n_spinups),
            constrained_layout=True,
            sharex=True,
            sharey=False,
        )
        if n_spinups == 1:
            axes = axes[np.newaxis, :]

        for row, df in enumerate(all_collocated):
            spinup   = df["spinup"].iloc[0]
            sp_color = SPINUP_COLORS.get(spinup, "#888888")

            for col, source in enumerate(sources):
                ax      = axes[row, col]
                s_color = SOURCE_COLORS[source]

                mask   = df["source"] == source
                x      = df.loc[mask, ocol].to_numpy()
                y      = df.loc[mask, f"{mvar}_model_gC_m2"].to_numpy()
                v      = np.isfinite(x) & np.isfinite(y)
                errors = y[v] - x[v]

                if errors.size < 5:
                    ax.text(0.5, 0.5, "insufficient data",
                            ha="center", va="center",
                            transform=ax.transAxes, color="#888888")
                    continue

                # ── Density histogram ──
                sns.histplot(
                    errors, ax=ax,
                    bins=min(50, max(12, errors.size // 25)),
                    stat="density",
                    color=s_color, alpha=0.30,
                    edgecolor="white", linewidth=0.3,
                    zorder=2,
                )

                # ── KDE curve in spinup accent colour ──
                kde_fn = gaussian_kde(errors, bw_method="scott")
                x_kde  = np.linspace(-xlim_abs, xlim_abs, 400)
                ax.plot(x_kde, kde_fn(x_kde),
                        color=sp_color, lw=2.2, zorder=4)

                # ── Shaded ±1σ region under the KDE ──
                sigma = float(np.std(errors))
                x_shade = np.linspace(-sigma, sigma, 200)
                ax.fill_between(x_shade, kde_fn(x_shade),
                                color=sp_color, alpha=0.12, zorder=3)

                # ── Zero-error reference ──
                ax.axvline(0, color="#444444", lw=1.0, ls="--", zorder=5)

                # ── Bias marker ──
                bias = float(np.mean(errors))
                ax.axvline(bias, color=sp_color, lw=1.4, ls=":", zorder=5)

                # ── Metrics box (placed away from KDE peak) ──
                rmse  = float(np.sqrt(np.mean(errors**2)))
                txt   = "\n".join([
                    f"$n$ = {errors.size:,}",
                    f"bias = {bias:+.2f}",
                    f"RMSE = {rmse:.2f}",
                    f"σ = {sigma:.2f}",
                ])
                ha   = "right" if bias > 0 else "left"
                xpos = 0.97   if ha == "right" else 0.03
                ax.text(
                    xpos, 0.97, txt,
                    transform=ax.transAxes, va="top", ha=ha,
                    size="small", linespacing=1.55,
                    family="monospace",
                    bbox=dict(boxstyle="round,pad=0.4", fc="white",
                              ec=sp_color, lw=1.2, alpha=0.88),
                    zorder=6,
                )

                ax.set_xlim(-xlim_abs, xlim_abs)
                ax.xaxis.set_major_locator(mticker.MaxNLocator(5, prune="both"))

                # Column header on top row only
                if row == 0:
                    ax.set_title(source, fontweight="bold", color=s_color, pad=4, size="medium")

                # Row label (spinup name) on left column only
                if col == 0:
                    ax.set_ylabel(
                        f"{spinup.replace('_', ' ')}\nDensity",
                        color=sp_color, fontweight="bold",
                        labelpad=6,
                    )
                else:
                    ax.set_ylabel("")

                # x-label on bottom row only
                if row == n_spinups - 1:
                    ax.set_xlabel("Model error  (gC m⁻²)", labelpad=4)
                else:
                    ax.set_xlabel("")

        fig.suptitle(
            f"{VAR_LABEL[mvar]}  —  model error distribution",
            fontweight="bold", y=1.01, size="large"
        )
        
        # Changed to PDF output
        out_pdf = OUT_DIR / f"error_hist_{mvar}_all_spinups.pdf"
        fig.savefig(out_pdf, dpi=300, bbox_inches="tight")
        plt.close(fig)
        print(f"Saved: {out_pdf}")

# %%
# ──────────────────────────────────────────────────────────────────────────────
# ENTRY POINT
# ──────────────────────────────────────────────────────────────────────────────

def main() -> None:
    print("Loading observations …")
    obs = load_observations()
    print(f"  SIBES rows: {(obs['source']=='SIBES').sum()}")
    print(f"  SUBES rows: {(obs['source']=='SUBES').sum()}")
    print(f"  Date range: {obs['date'].min().date()} → {obs['date'].max().date()}")

    all_collocated = []

    for spinup in SPINUP_NAMES:
        print(f"\nProcessing {spinup} …")
        collocated = collate_spinup(spinup, obs)
        if collocated is not None:
            all_collocated.append(collocated)
            for mvar in VALIDATION_VARS:
                n_matched = collocated[f"{mvar}_model_gC_m2"].notna().sum()
                print(f"  {mvar}: {n_matched:,} matched observations")

    if not all_collocated:
        print("\nNo collocated data produced – check paths and model output.")
        return

    # Save collocated tables per spinup
    for collocated in all_collocated:
        spinup = collocated["spinup"].iloc[0]
        sp_dir = OUT_DIR / spinup
        sp_dir.mkdir(parents=True, exist_ok=True)
        csv_path = sp_dir / "benthic_collocated_model_vs_obs.csv"
        collocated.to_csv(csv_path, index=False)
        print(f"Saved collocated table: {csv_path}")

    print("\nGenerating scatter plots …")
    plot_scatter_all_spinups(all_collocated)

    print("\nGenerating error histograms / KDE …")
    plot_error_histograms(all_collocated)

    print(f"\nAll output written to: {OUT_DIR}")


if __name__ == "__main__":
    main()
